# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 27.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
model.train(
    data="/kaggle/input/notebooks/shreydan/kitti-object-detection-yolov8n/kitti.yaml",
    epochs=10,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla P100-PCIE-16GB, 16269MiB)
# ...

# %%
import os

for dirname, _, filenames in os.walk('/kaggle/input'):
    print(dirname)
    break

# %%
import os

for dirname, dirs, files in os.walk('/kaggle/input'):
    print("FOLDER:", dirname)
    for d in dirs:
        print("  SUBFOLDER:", d)
    break

# %%
import os

for dirname, dirs, files in os.walk('/kaggle/input/datasets'):
    print("FOLDER:", dirname)
    for d in dirs:
        print("  SUBFOLDER:", d)
    break

# %%
import os

for dirname, dirs, files in os.walk('/kaggle/input/datasets/jubayerisfar'):
    print("FOLDER:", dirname)
    for d in dirs:
        print("  SUBFOLDER:", d)
    break

# %%
import os

for dirname, dirs, files in os.walk('/kaggle/input/datasets/jubayerisfar/kitti-dataset-yolo-format'):
    for file in files:
        if file.endswith('.yaml'):
            print(os.path.join(dirname, file))|

# %%
import os

for dirname, dirs, files in os.walk('/kaggle/input/datasets/jubayerisfar/kitti-dataset-yolo-format'):
    for file in files:
        if file.endswith('.yaml'):
            print(os.path.join(dirname, file))

# %%
model.train(
    data="/kaggle/input/datasets/jubayerisfar/kitti-dataset-yolo-format/Kitti Dataset Yolo Format/data.yaml",
    epochs=10,
    imgsz=640,
    batch=16
)

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

# %%
model.train(
    data="/kaggle/input/datasets/jubayerisfar/kitti-dataset-yolo-format/Kitti Dataset Yolo Format/data.yaml",
    epochs=10,
    imgsz=640,
    batch=16
)

# %%
model.predict(
    source="/kaggle/input/datasets/jubayerisfar/kitti-dataset-yolo-format/Kitti Dataset Yolo Format/images/val",
    save=True
)

# %%
import os

for dirname, dirs, files in os.walk("/kaggle/input/datasets/jubayerisfar/kitti-dataset-yolo-format/Kitti Dataset Yolo Format"):
    print("FOLDER:", dirname)
    for d in dirs:
        print("   SUB:", d)
    break

# %%
model.predict(
    source="/kaggle/input/datasets/jubayerisfar/kitti-dataset-yolo-format/Kitti Dataset Yolo Format/valid",
    save=True
)
